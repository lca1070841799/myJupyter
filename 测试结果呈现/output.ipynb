# %%
import pandas as pd

# %%
df=pd.read_csv('D:/datas/资料/研究生/实验室/智能客服/bert测试/00X/002-50/测试不同模型的语义相似度差异表-2020-04-17 20.35.32.csv')

# %%
df
# Out:
#     序号                                     相似句   base相似度    微调后相似度  base排名  \
# 0    0                         银行卡绑定失败,绑定银行卡失败  0.983631  0.989472       1
# 1    1              按期还款完后面就不会有多出的费用了把,按期还款是什么  0.842646  0.901009     309
# 2    2                   补扣不会影响征信什么的吧,补扣会影响信用吗  0.922809  0.968107       1
# 3    3                       今天扣会有影响吗,补扣会影响信用吗  0.882337  0.958858       4
# 4    4                Gps需要一直打开吗,操作好人贷是否需要开启定位  0.859999  0.948351     102
# 5    5                   绑定银行卡后下一步无法操作,绑定银行卡失败  0.936766  0.963376       1
# 6    6                  打电话不要钱吗,拨打我行人工客服电话是否收费  0.869749  0.946826      32
# 7    7                   绑卡不成功姓名与卡号不符合,绑定银行卡失败  0.911770  0.948914       1
# 8    8                    绑定银行卡不收费吧,绑定银行卡产生费用吗  0.946926  0.980151       1
# 9    9                   是什么原因导致绑卡失败的呢,绑定银行卡失败  0.839051  0.931858     253
# 10  10                    现在存上会影响信用吗？,补扣会影响信用吗  0.938389  0.965859       1
# ...
